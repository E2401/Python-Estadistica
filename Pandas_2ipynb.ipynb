# %%
import pandas as pd
import numpy as np 



DF = pd.read_csv('covid19tests.csv')

# %%
#Data Cleaning

DF['tests'] = DF['tests'].str.replace(",", "")
DF['tests'] = DF['tests'].str.replace("*", "")
DF['positive'] = DF['positive'].str.replace(",", "")
DF['positive'] = DF['positive'].str.replace("*", "")

DF['testper1m'] = DF['testper1m'].str.replace(",", "")

DF["tests"]= DF['tests'].astype(float)
DF["positive"]= DF['positive'].astype(float)
DF["testper1m"]= DF['testper1m'].astype(float)
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_1100\3712180232.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   DF['tests'] = DF['tests'].str.replace("*", "")
# C:\Users\John\AppData\Local\Temp\ipykernel_1100\3712180232.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   DF['positive'] = DF['positive'].str.replace("*", "")

# %%
DF.head(10)
# Out:
#   region     country alpha3code alpha2code     tests  positive    date  \
# 0    NaN   Argentina        ARG         AR    4843.0     966.0  31-Mar
# 1    NaN     Armenia        ARM         AM    3603.0     663.0   2-Apr
# 2    NaN   Australia        AUS         AU  277355.0    5358.0   3-Apr
# 3    NaN     Austria        AUT         AT   98343.0   11350.0   3-Apr
# 4    NaN  Azerbaijan        AZE         AZ   30000.0     443.0   3-Apr
# 5    NaN     Bahrain        BHR         BH   37996.0     668.0   3-Apr
# 6    NaN  Bangladesh        BGD         BD    1602.0      54.0   1-Apr
# 7    NaN    Barbados        BRB         BB     382.0      45.0   1-Apr
# 8    NaN     Belarus        BLR         BY   32000.0     362.0   3-Apr
# 9    NaN     Belgium        BEL         BE   18360.0    1486.0  18-Mar
#
#    testper1m  positiveper1m
# 0      107.0          199.0
# 1     1221.0           74.0
# 2    10919.0           19.0
# 3    11047.0          101.0
# 4     3031.0           15.0
# 5    24210.0           17.6
# 6       10.0           33.7
# 7     1331.0          118.0
# 8     3371.0           11.3
# 9     1594.0           81.0

# %%
DF.tail(10)
# Out:
#          region    country alpha3code alpha2code     tests  positive    date  \
# 101     Illinos         US        USA         US   43656.0    7695.0   2-Apr
# 102   Louisiana         US        USA         US   51086.0    9150.0   2-Apr
# 103    New York         US        USA         US  238965.0   92381.0   2-Apr
# 104  New Jersey         US        USA         US   59110.0   25590.0   2-Apr
# 105    Michigan         US        USA         US   22684.0   10791.0   2-Apr
# 106       Texas         US        USA         US   50679.0    4669.0   2-Apr
# 107  Washington         US        USA         US   79418.0    6585.0   1-Apr
# 108         NaN    Uruguay        URY         UY    1538.0     189.0  24-Mar
# 109         NaN  Venezuela        VEN         VE    1779.0     143.0  31-Mar
# 110         NaN    Vietnam        VNM         VN   73164.0     233.0   3-Apr
#
#      testper1m  positiveper1m
# 101     3445.0          176.0
# 102    10963.0          126.0
# 103    12284.0          387.0
# 104     6655.0          433.0
# 105     2264.0          476.0
# 106     1748.0           92.0
# 107    10429.0           86.0
# 108      443.0          123.0
# 109       62.0           80.4
# 110      760.0            3.2

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   region         31 non-null     object
#  1   country        111 non-null    object
#  2   alpha3code     110 non-null    object
#  3   alpha2code     111 non-null    object
#  4   tests          111 non-null    float64
#  5   positive       109 non-null    float64
#  6   date           111 non-null    object
#  7   testper1m      111 non-null    float64
#  8   positiveper1m  110 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 7.9+ KB

# %%
DF.shape
# Out:
# (111, 9)

# %%
DF.describe()
# Out:
#               tests       positive     testper1m  positiveper1m
# count  1.110000e+02     109.000000    111.000000     110.000000
# mean   8.244671e+04    9395.788991   5641.882883     105.740909
# std    1.797698e+05   28110.319628   7416.403319      99.158814
# min    1.800000e+01       0.000000     10.000000       0.000000
# 25%    7.263000e+03     443.000000    764.500000      31.675000
# 50%    3.021300e+04    1380.000000   3031.000000      79.200000
# 75%    6.710950e+04    6585.000000   8651.500000     143.750000
# max    1.350219e+06  241734.000000  57459.000000     476.000000

# %%
boxplot = DF.boxplot(column= ["tests","positive", "testper1m", "positiveper1m" ])

# %%
df_2 = DF[DF["testper1m"] >= 1000 ]
df_2
# Out:
#          region     country alpha3code alpha2code     tests  positive   date  \
# 1           NaN     Armenia        ARM         AM    3603.0     663.0  2-Apr
# 2           NaN   Australia        AUS         AU  277355.0    5358.0  3-Apr
# 3           NaN     Austria        AUT         AT   98343.0   11350.0  3-Apr
# 4           NaN  Azerbaijan        AZE         AZ   30000.0     443.0  3-Apr
# 5           NaN     Bahrain        BHR         BH   37996.0     668.0  3-Apr
# ..          ...         ...        ...        ...       ...       ...    ...
# 103    New York          US        USA         US  238965.0   92381.0  2-Apr
# 104  New Jersey          US        USA         US   59110.0   25590.0  2-Apr
# 105    Michigan          US        USA         US   22684.0   10791.0  2-Apr
# 106       Texas          US        USA         US   50679.0    4669.0  2-Apr
# 107  Washington          US        USA         US   79418.0    6585.0  1-Apr
#
#      testper1m  positiveper1m
# 1       1221.0           74.0
# 2      10919.0           19.0
# 3      11047.0          101.0
# 4       3031.0           15.0
# 5      24210.0           17.6
# ..         ...            ...
# 103    12284.0          387.0
# 104     6655.0          433.0
# 105     2264.0          476.0
# 106     1748.0           92.0
# 107    10429.0           86.0
#
# [81 rows x 9 columns]
