# %%
import pandas as pd
import numpy as np 



DF = pd.read_csv('covid19tests.csv')

#print(DF)

#DF.shape

#DF.ndim
#type(DF.info())


DF[["alpha3code", "date","tests", "positive" ]]

#boxplot = C.boxplot(column=["tests", "positive"])
print(DF)

#DF.info
A = DF.loc[99:107]
#print(A)
#DF.info

B = DF.loc[50:56]


 

print(B.describe())


boxplot = B.boxplot(column=['positiveper1m'])
# Out:
#          region     country alpha3code alpha2code    tests positive    date  \
# 0           NaN   Argentina        ARG         AR    4,843      966  31-Mar
# 1           NaN     Armenia        ARM         AM    3,603      663   2-Apr
# 2           NaN   Australia        AUS         AU  277,355    5,358   3-Apr
# 3           NaN     Austria        AUT         AT   98,343   11,350   3-Apr
# 4           NaN  Azerbaijan        AZE         AZ   30,000      443   3-Apr
# ..          ...         ...        ...        ...      ...      ...     ...
# 106       Texas          US        USA         US   50,679    4,669   2-Apr
# 107  Washington          US        USA         US   79,418    6,585   1-Apr
# 108         NaN     Uruguay        URY         UY    1,538      189  24-Mar
# 109         NaN   Venezuela        VEN         VE    1,779      143  31-Mar
# 110         NaN     Vietnam        VNM         VN   73,164      233   3-Apr
#
#     testper1m  positiveper1m
# ...

# %%
C = B[["tests", "positive" ]]
print(C)
# Out:
#       tests positive
# 50   60,507   15,333
# 51   12,069    3,782
# 52  128,286   46,065
# 53   12,943    4,098
# 54   32,100   10,353
# 55   40,724    5,273
# 56  120,320   10,111

# %%
C['tests'] = C['tests'].str.replace(",", "")
C['positive'] = C['tests'].str.replace(",", "")
C
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      tests positive
# 50   60507    60507
# 51   12069    12069
# 52  128286   128286
# 53   12943    12943
# 54   32100    32100
# 55   40724    40724
# 56  120320   120320

# %%
  type(C.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 50 to 56
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tests     7 non-null      object
#  1   positive  7 non-null      object
# dtypes: object(2)
# memory usage: 244.0+ bytes
# NoneType

# %%
G = C
#C["tests"].astype(float)
G["tests"]= G['tests'].astype(float)
G["positive"]= G['positive'].astype(float)

print(G)
# Out:
#        tests  positive
# 50   60507.0   60507.0
# 51   12069.0   12069.0
# 52  128286.0  128286.0
# 53   12943.0   12943.0
# 54   32100.0   32100.0
# 55   40724.0   40724.0
# 56  120320.0  120320.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
a = pd.concat([G,A  ],  axis=0)
a
# Out:
#         tests  positive      region country alpha3code alpha2code   date  \
# 50    60507.0   60507.0         NaN     NaN        NaN        NaN    NaN
# 51    12069.0   12069.0         NaN     NaN        NaN        NaN    NaN
# 52   128286.0  128286.0         NaN     NaN        NaN        NaN    NaN
# 53    12943.0   12943.0         NaN     NaN        NaN        NaN    NaN
# 54    32100.0   32100.0         NaN     NaN        NaN        NaN    NaN
# 55    40724.0   40724.0         NaN     NaN        NaN        NaN    NaN
# 56   120320.0  120320.0         NaN     NaN        NaN        NaN    NaN
# 99    92,500*     9,191  California      US        USA         US  2-Apr
# 100    80,356     9,008     Florida      US        USA         US  3-Apr
# 101    43,656     7,695     Illinos      US        USA         US  2-Apr
# 102    51,086     9,150   Louisiana      US        USA         US  2-Apr
# 103   238,965    92,381    New York      US        USA         US  2-Apr
# ...

# %%
A = DF.loc[99:107]
B = DF.loc[50:56]

C = pd.concat([A,B], axis=1)
C
# Out:
#          region country alpha3code alpha2code    tests positive   date  \
# 50          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 51          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 52          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 53          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 54          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 55          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 56          NaN     NaN        NaN        NaN      NaN      NaN    NaN
# 99   California      US        USA         US  92,500*    9,191  2-Apr
# 100     Florida      US        USA         US   80,356    9,008  3-Apr
# 101     Illinos      US        USA         US   43,656    7,695  2-Apr
# 102   Louisiana      US        USA         US   51,086    9,150  2-Apr
# 103    New York      US        USA         US  238,965   92,381  2-Apr
# ...
